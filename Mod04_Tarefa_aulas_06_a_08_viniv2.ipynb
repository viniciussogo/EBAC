# %% [markdown]
# # Tarefa 03
#
# - Leia os enunciados com atenção
# - Saiba que pode haver mais de uma resposta correta
# - Insira novas células de código sempre que achar necessário
# - Em caso de dúvidas, procure os Tutores
# - Divirta-se :)

# %%
import pandas as pd
import requests

# %% [markdown]
# ####  1) Lendo de APIs
# Vimos em aula como carregar dados públicos do governo através de um API (*Application Programming Interface*). No exemplo de aula, baixamos os dados de pedidos de verificação de limites (PVL) realizados por estados, e selecionamos apenas aqueles referentes ao estado de São Paulo.
#
# 1. Repita os mesmos passos feitos em aula, mas selecione os PVLs realizados por municípios no estado do Rio de Janeiro.
# 2. Quais são os três *status* das solicitações mais frequentes na base? Quais são suas frequências?
# 3. Construa uma nova variável que contenha o ano do **status**. Observe que ```data_status``` vem como tipo *object* no **DataFrame**. Dica: você pode usar o método ```.str``` para transformar o tipo da variável em string, em seguida um método como [**slice()**](https://pandas.pydata.org/docs/reference/api/pandas.Series.str.slice.html) ou [**split()**](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.str.split.html).
# 4. Indique a frequência de cada ano do campo construído no item (3).

# %%
# 1) Seu código aqui
url = "https://apidatalake.tesouro.gov.br/ords/sadipem/tt/pvl"
r = requests.get(url)

# %%
data_json = r.json()
print(data_json)
# Out:
# {'items': [{'id_pleito': 46992, 'tipo_interessado': 'Município', 'interessado': 'Chapecó', 'cod_ibge': 4204202, 'uf': 'SC', 'num_pvl': 'PVL02.001405/2021-88', 'status': 'Encaminhado à PGFN com manifestação técnica favorável', 'num_processo': '17944.103483/2021-89', 'data_protocolo': '2021-11-19T18:16:28Z', 'tipo_operacao': 'Operação contratual interna (com garantia da União)', 'finalidade': 'Infraestrutura', 'tipo_credor': 'Instituição Financeira Nacional', 'credor': 'Banco do Brasil S/A', 'moeda': 'Real', 'valor': 300000000, 'pvl_assoc_divida': 0, 'pvl_contradado_credor': 1, 'data_status': '29/11/2021'}, {'id_pleito': 47169, 'tipo_interessado': 'Município', 'interessado': 'Vitor Meireles', 'cod_ibge': 4219358, 'uf': 'SC', 'num_pvl': 'PVL02.003241/2021-23', 'status': 'Deferido (PVL-IF)', 'num_processo': None, 'data_protocolo': None, 'tipo_operacao': 'Operação contratual interna', 'finalidade': 'Aquisição de máquinas, equipamentos e veículos', 'tipo_credor': 'Instituição Financeira Na
# ...

# %%
data = pd.DataFrame(data_json['items'])
dados_rj = data[data['uf'] == 'RJ']
dados_rj
# Out:
#       id_pleito tipo_interessado          interessado  cod_ibge  uf  \
# 56        66685        Município            Queimados   3304144  RJ
# 105       65888        Município               Paraty   3303807  RJ
# 253       21660           Estado       Rio de Janeiro        33  RJ
# 339       67445        Município              Resende   3304201  RJ
# 620       10796        Município   Armação dos Búzios   3300233  RJ
# 824        9102           Estado       Rio de Janeiro        33  RJ
# 868       62991        Município       Paraíba do Sul   3303708  RJ
# 869       62992        Município       Paraíba do Sul   3303708  RJ
# 1043      69133        Município    Casimiro de Abreu   3301306  RJ
# 1069      60057        Município               Paraty   3303807  RJ
# 1143      11692        Município       Rio de Janeiro   3304557  RJ
# 1282       6644        Município   São João de Meriti   3305109  RJ
# 1341       6833           Estado       Rio de Janeiro        33  RJ
# ...

# %%
 # 2) Seu código aqui
status_frequencia = dados_rj['status'].value_counts()
status_frequencia.head(3)
# Out:
# status
# Deferido                                                 17
# Encaminhado à PGFN com manifestação técnica favorável    10
# Deferido (PVL-IF)                                         7
# Name: count, dtype: int64

# %%
# 3) Seu código aqui
dados_rj.loc[:, 'ano_status'] = dados_rj['data_status'].str.slice(6, 10)
dados_rj
# Out:
# <ipython-input-6-1bde16fa33dc>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dados_rj.loc[:, 'ano_status'] = dados_rj['data_status'].str.slice(6, 10)
#       id_pleito tipo_interessado          interessado  cod_ibge  uf  \
# 56        66685        Município            Queimados   3304144  RJ
# 105       65888        Município               Paraty   3303807  RJ
# 253       21660           Estado       Rio de Janeiro        33  RJ
# 339       67445        Município              Resende   3304201  RJ
# 620       10796        Município   Armação dos Búzios   3300233  RJ
# 824        9102           Estado       Rio de Janeiro        33  RJ
# 868       62991        Município       Paraíba do Sul   3303708  RJ
# ...

# %%
# 4) Seu código aqui
ano_frequencia = dados_rj['ano_status'].value_counts()
ano_frequencia
# Out:
# ano_status
# 2023    11
# 2019     6
# 2008     5
# 2013     4
# 2011     3
# 2010     3
# 2009     3
# 2012     3
# 2024     2
# 2007     2
# 2016     2
# 2014     2
# 2022     2
# 2018     1
# 2020     1
# 2002     1
# 2006     1
# Name: count, dtype: int64

# %% [markdown]
# ####  2) Melhorando a interação com o API
# Observe dois URLs de consultas diferentes, por exemplo o URL utilizado em aula, e o URL feito no exercício anterior. Compare-os e observe as diferenças.
#
# 1. Faça uma função em Python que recebe como argumento o UF da consulta e o tipo de interessado (```'Estado'```ou ```Município```), e que devolve os dados da consulta no formato *DataFrame*.
# 2. Quantas solicitações para o Estado podem ser consultadas para Minas Gerais com *status* em 'Arquivado por decurso de prazo' estão registradas?
# 3. Qual é o município da Bahia com mais solicitações deferidas?
# 4. Salve um arquivo .csv com os dados de solicitações da Bahia, com interessado = 'Estado'

# %%
#1) Seu código aqui

def consultar_pvl(uf, tipo_interessado):
    url = "https://apidatalake.tesouro.gov.br/ords/sadipem/tt/pvl"
    r = requests.get(url)
    data_json = r.json()
    data = pd.DataFrame(data_json['items'])

    # Filtrar pela UF e tipo de interessado
    dados_filtrados = data[(data['uf'] == uf) & (data['tipo_interessado'] == tipo_interessado)]

    return dados_filtrados
# Out:
#       id_pleito tipo_interessado   interessado  cod_ibge  uf  \
# 2492       9197           Estado  Minas Gerais        31  MG
# 2733      68204           Estado  Minas Gerais        31  MG
# 3278       7435           Estado  Minas Gerais        31  MG
# 3327      11054           Estado  Minas Gerais        31  MG
# 4059       5828           Estado  Minas Gerais        31  MG
#
#                    num_pvl                                             status  \
# 2492                  None  Encaminhado à PGFN com manifestação técnica fa...
# 2733  PVL02.003861/2023-24                    Em retificação pelo interessado
# 3278                  None  Encaminhado à PGFN com manifestação técnica fa...
# 3327                  None  Encaminhado à PGFN com manifestação técnica fa...
# 4059                  None  Encaminhado à PGFN com manifestação técnica fa...
#
#               num_processo        data_protocolo  \
# 2492  17944.000924/2009-03  2010-03-10T03:00:00Z
# ...

# %%
# 2) Seu código aqui

arquivado_mg = data[(data['uf'] == 'MG') & (data['status'] == 'Arquivado por decurso de prazo')]
quantidade_arquivado_mg = arquivado_mg.shape[0]
quantidade_arquivado_mg
# Out:
# 56

# %%
# 3) Seu código aqui
# Consultar dados de municípios da Bahia
dados_ba_municipio = consultar_pvl('BA', 'Município')

# Filtrar os deferidos
deferidos_ba = dados_ba_municipio[dados_ba_municipio['status'] == 'Deferido']

# Contar qual município tem mais deferimentos
municipio_mais_deferido = deferidos_ba['interessado'].value_counts()
municipio_mais_deferido.head(1)
# Out:
# interessado
# Luís Eduardo Magalhães    4
# Name: count, dtype: int64

# %%
# 4) Seu código aqui
# Consultar dados da Bahia com interessado 'Estado'
dados_ba_estado = consultar_pvl('BA', 'Estado')

# Salvar em um arquivo CSV
dados_ba_estado.to_csv('solicitacoes_bahia_estado.csv', index=False)

dados_ba_estado.head()
# Out:
#       id_pleito tipo_interessado interessado  cod_ibge  uf  \
# 1135      18515           Estado       Bahia        29  BA
# 1249      18583           Estado       Bahia        29  BA
# 2475      22572           Estado       Bahia        29  BA
# 2495      23723           Estado       Bahia        29  BA
# 2568      69633           Estado       Bahia        29  BA
#
#                    num_pvl                                             status  \
# 1135                  None                                           Deferido
# 1249                  None                                           Deferido
# 2475  00000.000000/2032-81                                 Arquivado pela STN
# 2495  PVL02.000640/2016-75  Encaminhado à PGFN com manifestação técnica fa...
# 2568  PVL02.001281/2024-83                    Em retificação pelo interessado
#
#               num_processo        data_protocolo  \
# 1135  19407.000040/2002-87  2002-06-21T03:00:00Z
# ...
