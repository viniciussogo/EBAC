# %% [markdown]
# # Livro para consulta:
# - https://jakevdp.github.io/PythonDataScienceHandbook/03.08-aggregation-and-grouping.html
# - https://jakevdp.github.io/PythonDataScienceHandbook/03.09-pivot-tables.html

# %% [markdown]
# # 1. Importando bibliotecas <a name="import"></a>
#
# <div style="text-align: right"
#
# [Voltar ao índice](#Contents)

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# # 2. Carregando o dataframe SINASC <a name="read"></a>
# <div style="text-align: right"
#
# [Voltar ao índice](#Contents)

# %%
sinasc_raw = pd.read_csv('SINASC_RO_2019.csv')
sinasc_raw.head()
# Out:
#    ORIGEM   CODESTAB  CODMUNNASC  LOCNASC  IDADEMAE  ESTCIVMAE  \
# 0       1  2679477.0      110001        1        19        5.0
# 1       1  2679477.0      110001        1        29        2.0
# 2       1  2679477.0      110001        1        37        9.0
# 3       1  2516500.0      110001        1        30        5.0
# 4       1  2516500.0      110001        1        30        2.0
#
#             ESCMAE  CODOCUPMAE  QTDFILVIVO  QTDFILMORT  ...  KOTELCHUCK  \
# 0      8 a 11 anos         NaN         0.0         0.0  ...           5
# 1      8 a 11 anos    999992.0         1.0         0.0  ...           5
# 2      8 a 11 anos    513205.0         2.0         0.0  ...           5
# 3  12 anos ou mais    231205.0         0.0         0.0  ...           4
# 4      8 a 11 anos    999992.0         1.0         0.0  ...           5
#
#   CONTADOR munResStatus munResTipo               munResNome  munResUf  \
# 0        1        ATIVO      MUNIC    Alta Floresta D'Oeste  Rondônia
# ...

# %%
sinasc_raw.columns
# Out:
# Index(['ORIGEM', 'CODESTAB', 'CODMUNNASC', 'LOCNASC', 'IDADEMAE', 'ESTCIVMAE',
#        'ESCMAE', 'CODOCUPMAE', 'QTDFILVIVO', 'QTDFILMORT', 'CODMUNRES',
#        'GESTACAO', 'GRAVIDEZ', 'PARTO', 'CONSULTAS', 'DTNASC', 'HORANASC',
#        'SEXO', 'APGAR1', 'APGAR5', 'RACACOR', 'PESO', 'IDANOMAL', 'DTCADASTRO',
#        'CODANOMAL', 'NUMEROLOTE', 'VERSAOSIST', 'DTRECEBIM', 'DIFDATA',
#        'DTRECORIGA', 'NATURALMAE', 'CODMUNNATU', 'CODUFNATU', 'ESCMAE2010',
#        'SERIESCMAE', 'DTNASCMAE', 'RACACORMAE', 'QTDGESTANT', 'QTDPARTNOR',
#        'QTDPARTCES', 'IDADEPAI', 'DTULTMENST', 'SEMAGESTAC', 'TPMETESTIM',
#        'CONSPRENAT', 'MESPRENAT', 'TPAPRESENT', 'STTRABPART', 'STCESPARTO',
#        'TPNASCASSI', 'TPFUNCRESP', 'TPDOCRESP', 'DTDECLARAC', 'ESCMAEAGR1',
#        'STDNEPIDEM', 'STDNNOVA', 'CODPAISRES', 'TPROBSON', 'PARIDADE',
#        'KOTELCHUCK', 'CONTADOR', 'munResStatus', 'munResTipo', 'munResNome',
# ...

# %% [markdown]
# # Tarefa 1

# %% [markdown]
# ### 1. Idade media das mães e dos pais por município (coluna munResNome)

# %%
sinasc_raw.groupby("munResNome")[["IDADEMAE", "IDADEPAI"]].mean()
# Out:
#                             IDADEMAE   IDADEPAI
# munResNome
# Alta Floresta D'Oeste      25.509091  29.137363
# Alto Alegre dos Parecis    24.850575  29.487500
# Alto Paraíso               25.466102  24.250000
# Alvorada D'Oeste           25.814433  31.408163
# Ariquemes                  25.540351  31.333333
# Buritis                    25.448718  30.516667
# Cabixi                     24.852941  33.000000
# Cacaulândia                24.906977  36.666667
# Cacoal                     26.708987  30.531685
# Campo Novo de Rondônia     25.141026  30.192308
# Candeias do Jamari         25.559524  29.615385
# Castanheiras               26.882353  30.333333
# Cerejeiras                 27.259843  31.292683
# Chupinguaia                25.494845  29.750000
# Colorado do Oeste          27.838384  34.250000
# Corumbiara                 24.745455  34.285714
# Costa Marques              24.921875  29.600000
# Cujubim                    24.622642  32.000000
# ...

# %% [markdown]
# ### 2. Peso médio dos bebes por sexo que nasceram no dia do seu aniversário por faixas de escolaridade mae
# Ex: Você, aluna(o), nasceu no dia 10/01, então você precisa filtrar o conjunto de dados nessa data e calcular o peso médio dos bebês de cada sexo por faixa de escolaridade da mãe.

# %%
sinasc_aniver = sinasc_raw[sinasc_raw['DTNASC'] == "2019-05-01"]

# %%
sinasc_aniver_filtrado = sinasc_aniver[["ESCMAE", "SEXO", "PESO"]]

# %%
sinasc_aniver_filtrado.groupby(["ESCMAE", "SEXO"]).mean()
# Out:
#                                   PESO
# ESCMAE          SEXO
# 1 a 3 anos      Feminino   3275.000000
# 12 anos ou mais Feminino   2709.000000
#                 Masculino  3285.166667
# 4 a 7 anos      Feminino   3112.142857
#                 Masculino  3096.428571
# 8 a 11 anos     Feminino   3131.468750
#                 Masculino  3555.812500

# %% [markdown]
# ### 3. Qual o municipio que nasceu menos bebe em 2019?
#     - qual a idade media, maxima, minima das maes nesse municipio?
#     - qual a idade media, maxima, minima dos pais nesse municipio?

# %%
nascimentos_por_municipio = sinasc_raw.groupby("munResNome").size().sort_values(ascending=True)
nascimentos_por_municipio
# Out:
# munResNome
# Município ignorado - RO         1
# Castanheiras                   17
# Pimenteiras do Oeste           20
# Parecis                        21
# Primavera de Rondônia          22
# São Felipe D'Oeste             28
# Cabixi                         34
# Rio Crespo                     35
# Teixeirópolis                  36
# Ministro Andreazza             39
# Novo Horizonte do Oeste        42
# Cacaulândia                    43
# Vale do Paraíso                45
# Theobroma                      47
# Nova União                     49
# Itapuã do Oeste                50
# Santa Luzia D'Oeste            51
# Vale do Anari                  54
# Corumbiara                     55
# Governador Jorge Teixeira      62
# Seringueiras                   77
# Campo Novo de Rondônia         78
# Urupá                          84
# Alto Alegre dos Parecis        87
# Mirante da Serra               92
# Monte Negro                    95
# Chupinguaia                    97
# ...

# %%
dados_castanheiras = sinasc_raw[sinasc_raw["munResNome"] == "Castanheiras"]
sinasc_castanheiras = dados_castanheiras.groupby("munResNome")[["IDADEMAE", "IDADEPAI"]]
sinasc_castanheiras.head()
# Out:
#       IDADEMAE  IDADEPAI
# 2067        18      17.0
# 2300        31      36.0
# 4512        22       NaN
# 5881        26      24.0
# 5952        32      29.0

# %%
estatisticas_castanheiras = sinasc_castanheiras.agg(["mean", "min", "max"])
estatisticas_castanheiras
# Out:
#                IDADEMAE           IDADEPAI
#                    mean min max       mean   min   max
# munResNome
# Castanheiras  26.882353  18  35  30.333333  17.0  42.0

# %% [markdown]
# ### 4. Qual o municipio que nasceu mais bebe no mês de março?
#     - qual a quantidade de filhos vivos media, maxima, minima nesse municipio?
#     - qual a idade media, maxima, minima dos pais nesse municipio?

# %%
sinasc_raw["DTNASC"] = pd.to_datetime(sinasc_raw["DTNASC"])
dados_marco = sinasc_raw[sinasc_raw["DTNASC"].dt.month == 3]

# %%
dados_marco.groupby("munResNome").size().sort_values(ascending=False)
# Out:
# munResNome
# Porto Velho                  744
# Ji-Paraná                    188
# Vilhena                      148
# Ariquemes                    141
# Cacoal                       133
# Jaru                          80
# Guajará-Mirim                 75
# Rolim de Moura                69
# Ouro Preto do Oeste           67
# Pimenta Bueno                 62
# Buritis                       59
# Nova Mamoré                   53
# Espigão D'Oeste               44
# Machadinho D'Oeste            44
# São Miguel do Guaporé         41
# Candeias do Jamari            33
# São Francisco do Guaporé      31
# Alta Floresta D'Oeste         31
# Presidente Médici             29
# Costa Marques                 24
# Alvorada D'Oeste              22
# Alto Paraíso                  22
# Monte Negro                   20
# Nova Brasilândia D'Oeste      20
# Colorado do Oeste             19
# Seringueiras                  19
# Chupinguaia                   18
# Cujubim                       17
# ...

# %%
dados_portovelho = sinasc_raw[sinasc_raw["munResNome"] == "Porto Velho"]

# %%
dados_portovelho.groupby("munResNome")[["QTDFILVIVO", "IDADEMAE", "IDADEPAI"]].agg(["mean", "min", "max"])
# Out:
#             QTDFILVIVO             IDADEMAE           IDADEPAI
#                   mean  min   max      mean min max       mean   min   max
# munResNome
# Porto Velho   1.167236  0.0  12.0  26.31267  12  47  32.352679  16.0  65.0

# %% [markdown]
# ### Analise as respostas encontradas, tire algum insight delas, conte pra gente algo encontrado nos dados. Algo que você julgue relevante e novo pra você.

# %% [markdown]
# Exemplo:
# - Ah, descobri que a idade mediana das mulheres que deram a luz no ano de 2019 dos municipios x é maior que y.

# %% [markdown]
# - Descobri que a quantidade de anos estudados é inversamente proporcional quantidade de filhos que a mulher tem.

# %%
media_idade_mae = sinasc_raw.groupby("ESCMAE")["QTDFILVIVO"].mean().sort_values(ascending=False)
media_idade_mae
# Out:
# ESCMAE
# Nenhuma            3.675000
# 1 a 3 anos         2.397980
# 4 a 7 anos         1.554003
# 8 a 11 anos        0.964274
# 12 anos ou mais    0.723574
# Name: QTDFILVIVO, dtype: float64

# %%
sinasc_raw.dtypes
# Out:
# ORIGEM          int64
# CODESTAB      float64
# CODMUNNASC      int64
# LOCNASC         int64
# IDADEMAE        int64
#                ...
# munResUf       object
# munResLat     float64
# munResLon     float64
# munResAlt     float64
# munResArea    float64
# Length: 69, dtype: object

# %%
sinasc_raw.select_dtypes(exclude=['int64','float64'])
# Out:
#                 ESCMAE         GESTACAO GRAVIDEZ    PARTO      DTNASC  \
# 0          8 a 11 anos  37 a 41 semanas    Única  Cesáreo  2019-02-19
# 1          8 a 11 anos  37 a 41 semanas    Única  Cesáreo  2019-02-21
# 2          8 a 11 anos  37 a 41 semanas    Única  Cesáreo  2019-02-25
# 3      12 anos ou mais  37 a 41 semanas    Única  Cesáreo  2019-03-20
# 4          8 a 11 anos  37 a 41 semanas    Única  Cesáreo  2019-03-23
# ...                ...              ...      ...      ...         ...
# 27023  12 anos ou mais  32 a 36 semanas    Única  Cesáreo  2019-12-13
# 27024      8 a 11 anos  37 a 41 semanas    Única  Vaginal  2019-10-04
# 27025      8 a 11 anos  37 a 41 semanas    Única  Cesáreo  2019-08-02
# 27026      8 a 11 anos  32 a 36 semanas    Única  Vaginal  2019-12-23
# 27027      8 a 11 anos  37 a 41 semanas    Única  Cesáreo  2019-12-27
#
#             SEXO RACACOR  DTCADASTRO CODANOMAL VERSAOSIST   DTRECEBIM  \
# ...

# %%
sinasc_raw.columns
# Out:
# Index(['ORIGEM', 'CODESTAB', 'CODMUNNASC', 'LOCNASC', 'IDADEMAE', 'ESTCIVMAE',
#        'ESCMAE', 'CODOCUPMAE', 'QTDFILVIVO', 'QTDFILMORT', 'CODMUNRES',
#        'GESTACAO', 'GRAVIDEZ', 'PARTO', 'CONSULTAS', 'DTNASC', 'HORANASC',
#        'SEXO', 'APGAR1', 'APGAR5', 'RACACOR', 'PESO', 'IDANOMAL', 'DTCADASTRO',
#        'CODANOMAL', 'NUMEROLOTE', 'VERSAOSIST', 'DTRECEBIM', 'DIFDATA',
#        'DTRECORIGA', 'NATURALMAE', 'CODMUNNATU', 'CODUFNATU', 'ESCMAE2010',
#        'SERIESCMAE', 'DTNASCMAE', 'RACACORMAE', 'QTDGESTANT', 'QTDPARTNOR',
#        'QTDPARTCES', 'IDADEPAI', 'DTULTMENST', 'SEMAGESTAC', 'TPMETESTIM',
#        'CONSPRENAT', 'MESPRENAT', 'TPAPRESENT', 'STTRABPART', 'STCESPARTO',
#        'TPNASCASSI', 'TPFUNCRESP', 'TPDOCRESP', 'DTDECLARAC', 'ESCMAEAGR1',
#        'STDNEPIDEM', 'STDNNOVA', 'CODPAISRES', 'TPROBSON', 'PARIDADE',
#        'KOTELCHUCK', 'CONTADOR', 'munResStatus', 'munResTipo', 'munResNome',
# ...
